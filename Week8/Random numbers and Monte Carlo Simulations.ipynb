# %%
import numpy.random

# %%
print numpy.random.random(5) #print 5 uniformly distributed numbers between 0 & 1
# Out:
# [ 0.35349906  0.97539261  0.61442259  0.45691397  0.03747794]

# %%
print numpy.random.random(5) #prints different set of 5
# Out:
# [ 0.56800656  0.67057275  0.44962604  0.36217144  0.80097792]

# %%
numpy.random.seed(4242) #set the seed

# %%
print "Using seed = 4242:"
print numpy.random.random(5)
# Out:
# Using seed = 4242:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#change back
numpy.random.seed(None)

#print another 5 with random seed
print "Using seed = None:"
print numpy.random.random(5)
# Out:
# Using seed = None:
# [ 0.2968129   0.32129943  0.69819815  0.60896295  0.74468925]

# %%
#reset seed to 4242...get the same output
numpy.random.seed(4242)
print "Using seed = 4242, we should get the same numbers as before"
print numpy.random.random(5)
# Out:
# Using seed = 4242, we should get the same numbers as before
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#reset the seed
numpy.random.seed(None)
z = numpy.random.random(100000)
hist(z,100,normed=True)
plot([0,1.],[1.,1.], 'r-', lw=3)
xlabel("x",fontsize=20)
ylabel("sample probablility",fontsize=20)
show()

# %% [markdown]
# #### Example 1: Analytic Inverse CDF Transform

# %%
x = arange(0.,pi+0.001,0.01)
f = lambda x: sin(x)/2.
F = lambda x: (cos(0)-cos(x))/2.
    
plot(x,f(x), label='True distribution',lw=3)
plot(x,F(x),label='Cumulative function',lw=3)

xlim(0,3.5)
ylim(0,1.1)

legend(loc=0)
show()

# %%
#number of samples
N = 10000

#N random numbers between 0 and 1
z = numpy.random.random_sample(N);

#inverse CDF
Finv = lambda z: arccos(cos(0)-2*z)

#sampled x values
xsamples = Finv(z);

#how do they compare to the original?
hist(xsamples,50,normed=True,label="Sampled distribution")
plot(x,f(x),label='True distribution',lw=3,color='red')

xlim(0,pi)
ylim(0,.7)

legend(loc=0)

# %% [markdown]
# #### Exercise 1. Exponential function - analytic

# %% [markdown]
# a) Determine the CDF F(x) for this function analytically and invert it analytically to obtain $F^{-1}$.

# %% [markdown]
# $F(x) =\int_0^{\infty}\lambda e^{-\lambda x}dx$

# %%
F = lambda x: e**(-x)
CDF = lambda x: 1 - e**(-x)
Finv = lambda z: log(-z+1)

# %% [markdown]
# b) Plot the function and CDF on the same plot over the range 0 <= x <= 5. Let $\lambda$ = 1

# %%
x=arange(0,5+0.001,0.01)
plot(x,F(x), label = "True Distribution", lw=3, color = "aqua")
plot(x,CDF(x), label = "CDF", lw=3, color = "orange")

legend()

# %% [markdown]
# c) Write a program to generate 10,000 samples according to the distribution of f(x). Plot a histogram of the resulting samples, using 50 bins, along with the true distribution.

# %%
N=10000
z = numpy.random.random_sample(N)
xsamples = Finv(z)

hist(xsamples,50,normed=True,label="Sample Distribution", color = "purple")
plot(x,f(x),label= "True Distribution", lw=3, color = "aqua")

xlim(0,5)
ylim(0,1)

legend(loc=0)
show()

# %% [markdown]
# #### Exercise 2. Exponential Function - Numerical

# %% [markdown]
# a) Write a program to implement the numerical inverse CDF transform algorithm for the exponential function from Exercise 1. You may wish to consult the numpy documentation or using the functions "cumsum" and "searchsorted". Let $\lambda$ = 1.
