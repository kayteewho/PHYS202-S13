# %% [markdown]
# #### Problem 1

# %% [markdown]
# $\psi_k(x) =A\frac{ik - atanh(ax)}{ik+a}e^{+ikx}$

# %% [markdown]
# $v_1 = m_2\sqrt{\frac{2G}
# M}(\frac{1}r-\frac{1}{r_0})$

# %% [markdown]
# $f(\Theta)=\frac{\hbar}p\displaystyle\sum_{\ell=0}^\infty(2\ell+1)e^{\iota\delta\ell}sin\delta_{\ell}P_{\ell}(cos\Theta)$

# %% [markdown]
# $\frac{d\sigma}{d\Omega}=\frac{\kappa\Pi^2(\Pi-\Theta)}{mu_0^2\Theta^2(2\Pi-\Theta)^2sin\Theta}$

# %% [markdown]
# $\langle{f}\rangle=\frac{1}\tau\int_0^{\tau}f(t)dt$

# %% [markdown]
# $\Omega_S=w\frac{sin\alpha}{sin\Theta}=\frac{L}{\lambda_1}=w\frac{\sqrt{\lambda_3^2+(\lambda_1^2-\lambda_3^2)sin\alpha}}{\lambda_1}$

# %% [markdown]
# #### Problem 2

# %%
i=1j
x=arange(-pi,pi+.08,.08)

k=0
U=-(1/cosh(x))**2 
psi = ((i*k-tanh(x))/(i*k+1))
psisquared=psi.conjugate()*psi
xticks(np.arange(-pi,pi+.08,pi/2), ("$-\pi$", "$-\pi/2$", "0.0", "$\pi/2$", "\pi$"))
plot(x,U, color="blue", linewidth=3, label="$U(x)$")
plot(x,psisquared, color="red", linewidth=3,label="$\psi^2, k=0.0$")

k=.5
psi = ((i*k-tanh(x))/(i*k+1))
psisquared=psi.conjugate()*psi
plot(x,psisquared, color="red", linestyle = '--', linewidth=3,label="$\psi^2, k=0.5$")

k=1
psi = ((i*k-tanh(x))/(i*k+1))
psisquared=psi.conjugate()*psi
plot(x,psisquared, color="red", linestyle = '-.', linewidth=3,label="$\psi^2, k=1.0$")

k=2
psi = ((i*k-tanh(x))/(i*k+1))
psisquared=psi.conjugate()*psi
plot(x,psisquared, color="red", linestyle = ':', linewidth=3,label="$\psi^2, k=2.0$")

xlabel("$x(rad)$",fontsize=18)
ylabel("$U(x),\psi^2(x)$", fontsize=18)
title("Probability Graph", fontsize=21)
legend(loc="lower left", prop={"size":7.0})

grid(True)

# %%
# c)
data = loadtxt('/nfshome/kahu/sunspots.txt',float)
x = data[:,0]
y = data[:,1]
a = np.zeros(1000)
b = np.zeros(1000)
avg = np.zeros(1000)
tot = 0
for i in range(1000):
    a[i] = x[i]
    b[i] = y[i]
    tot += y[i]
avg[i] = tot / i
plot(a, b, lw = 1, label = "Sunspots")
plot(a, avg, lw = 5, label = "Average")
xlabel("Months")
ylabel("Amount of Sunspots")
title("First 1000 Sunspots")
legend()

# %% [markdown]
# #### Problem 3

# %% [markdown]
# #### Problem 4

# %%
# a) 
data = loadtxt("/nfshome/kahu/stars.txt",float)
x = data[:,0]
y = data[:,1]
pylab.scatter(x,y, color="turquoise",linewidth=1,label="Temperature vs Absolute Magnitude",s=0.5)
xlabel("Temperature(K)",fontsize=18)
ylabel("Absolute Magnitude",fontsize=18)
title("Temperature vs Absolute Magnitude", fontsize=21)
legend()

# %%
# b)
data = loadtxt("/nfshome/kahu/stars.txt",float)
a = data[:,0]
b = data[:,1]

ax = gca()
ax.annotate('Red Giants',xy=(4000,2),xytext=(2800,2.0),arrowprops=dict(facecolor='black',shrink=0.02))
ax.annotate('Main Sequence Stars',xy=(6100,4.5),xytext=(14000,4),arrowprops=dict(facecolor='black',shrink=0.02))
ax.annotate('Blue Stars',xy=(12000,0),xytext=(12000,-3.0),arrowprops=dict(facecolor='black',shrink=0.02))
ax.annotate('White Dwarfs',xy=(8000,13),xytext=(12000,15.0),arrowprops=dict(facecolor='black',shrink=0.02))
pylab.scatter(x,y, color="turquoise",linewidth=1,label="Temperature",s=0.5)
xlabel("Temperature(K)",fontsize=18)
ylabel("Stellar Magnitude",fontsize=18)
title("Temperature vs Stellar Magnitude", fontsize=21)
legend()

xlim(16000,-1)
ylim(20,-5)
# Out:
# (20, -5)

# %% [markdown]
# #### Problem 5

# %%
# a)
data = loadtxt("/nfshome/kahu/sunspots.txt",float)
x = data[:,0]
y = data[:,1]

plot(x/12,y, color="blue",linewidth=1,label="Sunspots vs Time")
xlabel("Time(yrs)",fontsize=18)
ylabel("Sunspots",fontsize=18)
title("Sunspots vs Time", fontsize=21)
legend()

# %%
# b)
A=x[:1000]
B=y[:1000]
plot(A/12,B,color="green",linewidth=.5,label="Amount of Sunspots")

xlabel("Time(yrs)",fontsize=18)
ylabel("Sunspots",fontsize=18)
title("The First 1000 Sunspots",fontsize=21)
legend()

# %%
# c)
data = loadtxt('/Users/kahu/Desktop/sunspots.txt',float)
x = data[:,0]
y = data[:,1]
a = np.zeros(1000)
b = np.zeros(1000)
avg = np.zeros(1000)
tot = 0
for i in range(1000):
    a[i] = x[i]
    b[i] = y[i]
    tot += y[i]
    avg[i] = tot / i

    


plot(a, b, lw = 1, label = "Sunspots")
plot(a, avg, lw = 5, label = "Average")
xlabel("Months")
ylabel("# of Sunspots")
title("First 1000 Sunspots since 1749")
legend()
